# %%
'''
Diane Granger
dianeegranger@gmail.com

Python Zero to Hero 
LetsUpgrade
Instructor:  Mr. Saikiran Sondarkar, Python Expert and Chief Upgrader
Monday, October 25, 2021 - Friday, October 29, 2021

Assignment Day 3 - 1 (Wednesday, October 27, 2021)

You all are pilots, you have to land a plane, the altitude required for landing 
a plane is 1000ft, if it is less than that tell pilot to land the plane, or if it 
is more than that but less than 5000 ft ask the pilot to “come down to 1000 ft”, 
else if it is more than 5000ft ask the pilot to “go around and try later”.

'''

def landing(alt) :

  if alt <= 1000 :
    print("Please land the plane.")
  
  elif alt > 1000 and alt < 5000 :
    print("Please come down to 1000 ft.")
  
  elif alt > 5000 :
    print("Please go around and try again later.")

alt = 0
altitude = 0

# %%
# case:  alt < 1000
altitude = int(input("Enter altitude: "))
landing(altitude)
# Out:
# Enter altitude: 800
# Please land the plane.

# %%
# case:  alt = 1000
altitude = int(input("Enter altitude: "))
landing(altitude)
# Out:
# Enter altitude: 1000
# Please land the plane.

# %%
# case:  alt > 1000 and alt < 5000
altitude = int(input("Enter altitude: "))
landing(altitude)
# Out:
# Enter altitude: 4000
# Please come down to 1000 ft.

# %%
# case:  alt > 5000
altitude = int(input("Enter altitude: "))
landing(altitude)
# Out:
# Enter altitude: 7000
# Please go around and try again later.

# %%
'''
Diane Granger
dianeegranger@gmail.com


Python Zero to Hero 
LetsUpgrade 
Monday, October 25, 2021 - Friday, October 29, 2021
Instructor:  Mr. Saikiran Sondarkar, Python Expert and Chief Upgrader
Monday, October 25, 2021 - Friday, October 29, 2021

Assignment Day 3 - 2 (Wednesday, October 27, 2021)

Ankit's Maze
Ankit is in maze. The command center sent him a string which decodes to come 
out from the maze. 
He is initially at (0, 0).
String contains L, R, U, D denoting left, right, up and down.
In each command he will traverse 1 unit distance in the respective direction.

For example if he is at (2, 0) and the command is L he will go to (1, 0).

You guys just need to make the flow of the logic which updates the position 
after taking input from L, R, U, D 
     
'''

# Antik's Maze
def mazeExit(path) :
  leftCtr = 0 
  rightCtr = 0
  upCtr = 0 
  downCtr = 0

  for i in path :
    if (i == 'L') :
      leftCtr += 1
    elif (i == 'R') :
      rightCtr += 1
    elif (i == 'U') :
      upCtr += 1
    elif (i == 'D') :
      downCtr += 1
  
  # maze exit position
  print("Anzit's Exit Position: (", (rightCtr - leftCtr),
      ", ", (upCtr - downCtr), ")")

# Ankit's path out of maze
path = "UUULLLDDRR"

# start the maze walk
mazeExit(path)
# Out:
# Anzit's Exit Position: ( -1 ,  1 )
